# %%
# GENERAL IMPORTS
import matplotlib.pyplot as plt
import requests, re
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin
from tqdm import tqdm

plt.rcParams['image.cmap'] = 'inferno'

# %%
# DOWNLOAD DATA
archive_url = "https://noaadata.apps.nsidc.org/NOAA/G02135/north/daily/geotiff/"
name_pattern = re.compile(r".*extent_v4.0.tif$")
data_dir = "images"
max_workers = 20

# %%
def download_recursive(url, outdir, pattern, pbar):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    for link in soup.find_all("a")[1:]:
        href = link.get("href")
        full_url = urljoin(url, href)

        if href.endswith("/"):
            subdir = os.path.join(outdir, os.path.basename(href.strip("/")))
            download_recursive(full_url, subdir, pattern, pbar)
        elif pattern.match(href):
            os.makedirs(outdir, exist_ok=True)
            filename = os.path.join(outdir, os.path.basename(full_url))
            if not os.path.exists(filename):
                with open(filename, "wb") as f:
                    f.write(requests.get(full_url).content)
            pbar.update(1)

with tqdm(desc="Downloading files", unit="file", total=15000) as pbar:
    download_recursive(archive_url, data_dir, name_pattern, pbar)
# Out:
# Downloading files:   8%|▊         | 1130/15000 [01:06<13:32, 17.06file/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 21
#      18             pbar.update(1)
#      20 with tqdm(desc="Downloading files", unit="file", total=15000) as pbar:
# ---> 21     download_recursive(archive_url, data_dir, name_pattern, pbar)
#
# Cell In[3], line 11, in download_recursive(url, outdir, pattern, pbar)
#       9 if href.endswith("/"):
#      10     subdir = os.path.join(outdir, os.path.basename(href.strip("/")))
# ---> 11     download_recursive(full_url, subdir, pattern, pbar)
#      12 elif pattern.match(href):
#      13     os.makedirs(outdir, exist_ok=True)
#
# Cell In[3], line 2, in download_recursive(url, outdir, pattern, pbar)
#       1 def download_recursive(url, outdir, pattern, pbar):
# ----> 2     r = requests.get(url)
#       3     soup = BeautifulSoup(r.text, "html.parser")
#       5     for link in soup.find_all("a")[1:]:
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\urllib3\connection.py:790, in HTTPSConnection.connect(self)
#     787     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     788     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 790     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     791         sock=sock,
#     792         cert_reqs=self.cert_reqs,
#     793         ssl_version=self.ssl_version,
#     794         ssl_minimum_version=self.ssl_minimum_version,
#     795         ssl_maximum_version=self.ssl_maximum_version,
#     796         ca_certs=self.ca_certs,
#     797         ca_cert_dir=self.ca_cert_dir,
#     798         ca_cert_data=self.ca_cert_data,
#     799         cert_file=self.cert_file,
#     800         key_file=self.key_file,
#     801         key_password=self.key_password,
#     802         server_hostname=server_hostname_rm_dot,
#     803         ssl_context=self.ssl_context,
#     804         tls_in_tls=tls_in_tls,
#     805         assert_hostname=self.assert_hostname,
#     806         assert_fingerprint=self.assert_fingerprint,
#     807     )
#     808     self.sock = sock_and_verified.socket
#     810 # If an error occurs during connection/handshake we may need to release
#     811 # our lock so another connection can probe the origin.
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\urllib3\connection.py:969, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     966     if is_ipaddress(normalized):
#     967         server_hostname = normalized
# --> 969 ssl_sock = ssl_wrap_socket(
#     970     sock=sock,
#     971     keyfile=key_file,
#     972     certfile=cert_file,
#     973     key_password=key_password,
#     974     ca_certs=ca_certs,
#     975     ca_cert_dir=ca_cert_dir,
#     976     ca_cert_data=ca_cert_data,
#     977     server_hostname=server_hostname,
#     978     ssl_context=context,
#     979     tls_in_tls=tls_in_tls,
#     980 )
#     982 try:
#     983     if assert_fingerprint:
#
# File ~\Repositories\CS163\.venv\Lib\site-packages\urllib3\util\ssl_.py:458, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456 if ca_certs or ca_cert_dir or ca_cert_data:
#     457     try:
# --> 458         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     459     except OSError as e:
#     460         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
import os, re
import numpy as np
from PIL import Image

# count matching files
n_files = sum(1 for root, _, files in os.walk(data_dir)
              for file in files if name_pattern.match(file))

img_shape = (448, 304, 3)
images = np.zeros((n_files, *img_shape), dtype='uint8')
dates = np.zeros(n_files, dtype='datetime64[D]')

idx = 0
for root, _, files in tqdm(os.walk(data_dir)):
    for file in files:
        if name_pattern.match(file):
            path = os.path.join(root, file)

            # load image
            img = np.array(Image.open(path).convert('RGB'), dtype='uint8')
            images[idx] = img

            # extract date
            m = re.search(r'_(\d{8})_', file)
            date_str = m.group(1)
            date_iso = f"{date_str[:4]}-{date_str[4:6]}-{date_str[6:]}"
            dates[idx] = np.datetime64(date_iso, 'D')

            idx += 1
# Out:
# 613it [00:57, 10.65it/s]

# %%
# CALCULATE AREA
pixel_size = 25
n_images = images.shape[0]
areas = np.zeros(n_images, dtype='int64')

for i in tqdm(range(n_images)):
    mask = np.all(images[i] == 255, axis=-1)
    areas[i] = np.sum(mask) * pixel_size**2
# Out:
# 100%|██████████| 15484/15484 [01:34<00:00, 163.23it/s]

# %%
# CALCULATE AGE OF SEA ICE
n_images, H, W, _ = images.shape
counter = np.zeros((H, W), dtype=float)
age_stack = np.zeros((n_images, H, W), dtype=float)

for i in tqdm(range(1, n_images)):
    img = images[i]
    mask = np.all(img == 255, axis=-1)

    delta_days = (dates[i] - dates[i-1]).astype(int)
    counter = np.where(mask, counter + delta_days, 0)
    age_stack[i] = counter
# Out:
#   0%|          | 0/15483 [00:00<?, ?it/s]

# %%
# CALCULATE LAST TIME FROZEN DATE
last_white_date = np.zeros(img_shape[:2], dtype='datetime64[D]')

for i in tqdm(range(len(images)), total=len(images)):
    mask = np.all(images[i] == 255, axis=-1)
    last_white_date[mask] = dates[i]
# Out:
#   0%|          | 0/15484 [00:00<?, ?it/s]

# %%
years = last_white_date.astype('datetime64[Y]').astype(int) + 1970

plt.figure(figsize=(8,6))
im = plt.imshow(years)
cbar = plt.colorbar(im)
cbar.set_label("Year")
plt.title("Last time frozen")
plt.axis("off")
plt.show()

# %%
idx = 14000

plt.figure(figsize=(6,6))
plt.imshow(age_stack[idx] / 365.25, interpolation='nearest', vmin=0, vmax=4)
plt.title(f"{dates[idx]}")
plt.axis('off')
plt.colorbar(label='Ice age [years]')
plt.show()

# %%
day_of_year = (dates - dates.astype('datetime64[Y]')).astype(int) + 1
year = dates.astype('datetime64[Y]').astype(int) + 1970

plt.figure(figsize=(10,5))
scatter = plt.scatter(day_of_year, areas, c=year, cmap='inferno', s=5)
plt.xlabel("Day of Year")
plt.ylabel("Area [km²]")
plt.title("Area vs Day of Year (colored by year)")
plt.xticks(range(0, 366, 30))
plt.colorbar(scatter, label='Year')
plt.tight_layout()
plt.show()
